# %%
from json import load
from pathlib import PurePath
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as s
import wordcloud as wordcloud
from wordcloud import STOPWORDS
from PIL import Image

# %%
user_json_path = PurePath("../../data/processed_c2_data/")
user_raw_path = PurePath("../../data/clarkson2_files/")
user_list = [user for user in os.listdir(user_raw_path) if user != ".DS_Store"]

# %%
ocnt = "occurence_count"
tvec = "timing_vectors"
first_user = user_list[0]
path_to_first_user = PurePath(user_json_path, PurePath(f"user_{first_user}.json"))

with open(path_to_first_user, "r") as f:
    user_dict = load(f)

# %%
word_occurences = [(key, user_dict[key][ocnt]) for key in user_dict]
word_occurences
# Out:
# [('HOW', 32),
#  ('T', 97),
#  ('MAIL', 8),
#  ('GOOGLE', 9),
#  ('JOHN', 8),
#  ('MATTICK', 8),
#  ('FCHAPTER', 1),
#  ('PROBLEM', 22),
#  ('E', 153),
#  ('DRUID', 2),
#  ('SYSTEM', 5),
#  ('LOD', 1),
#  ('GGER', 1),
#  ('KEYST', 1),
#  ('TROI', 1),
#  ('XX', 140),
#  ('SO', 26),
#  ('THIS', 71),
#  ('THING', 2),
#  ('WILL', 67),
#  ('LOG', 1),
#  ('EVERYTHING', 5),
#  ('THAT', 79),
#  ('I', 121),
#  ('TYPE', 2),
#  ('NEATO', 1),
#  ('X', 1017),
#  ('XXX', 81),
#  ('XXXXXX', 7),
#  ('XXXX', 30),
#  ('XXXXX', 16),
#  ('Z', 37),
#  ('XXXXXXXXX', 3),
#  ('SD', 6),
#  ('DWD', 1),
#  ('GAMEPAD', 1),
#  ('MOE', 1),
#  ('DE', 6),
#  ('A', 294),
#  ('FOR', 89),
#  ('SUPERCRATE', 1),
#  ('BOTX', 1),
#  ('TED', 2),
#  ('YOU', 36),
#  ('HAVE', 43),
#  ('CONTRIBUTED', 2),
#  ('KEYSTROKES', 1),
#  ('BEFORE', 4),
#  ('SESSION', 2),
#  ('LO', 2),
#  ('KEYSTROKE', 3),
#  ('LOGGER', 2),
#  ('TO', 242),
#  ('REFRESH', 1),
#  ('THE', 568),
#  ('KEY', 5),
#  ('COUND', 1),
#  ('ON', 53),
#  ('SOFE', 1),
#  ('TWARE', 1),
#  ('TEXT', 4),
#  ('ADVENTURE', 2),
#  ('GAMES', 6),
#  ('LINE', 5),
#  ('PPPPPPPPPP', 1),
#  ('XXXXXXX', 1),
#  ('XXXXXXXX', 1),
#  ('XXXXXXXXXX', 2),
#  ('S', 156),
#  ('NOTES', 4),
#  ('MATH', 1),
#  ('CLASS', 2),
#  ('LAPLACE', 1),
#  ('EQUATIONIN', 1),
#  ('IN', 129),
#  ('POLAT', 1),
#  ('R', 60),
#  ('C', 69),
#  ('SCTRIP', 1),
#  ('D', 89),
#  ('Q', 8),
#  ('COINBASE', 1),
#  ('RACHET', 2),
#  ('B', 50),
#  ('JO', 3),
#  ('MY', 12),
#  ('BITCOIN', 5),
#  ('PASSO', 1),
#  ('WOR', 3),
#  ('WHAT', 37),
#  ('IS', 143),
#  ('HIGHEST', 1),
#  ('HAS', 14),
#  ('EVER', 2),
#  ('BEEN', 9),
#  ('G', 27),
#  ('MINE', 2),
#  ('PC', 1),
#  ('GROUP', 16),
#  ('M', 56),
#  ('MINIMUM', 2),
#  ('PROCESSING', 1),
#  ('POWER', 7),
#  ('VIS', 2),
#  ('V', 57),
#  ('CAPABLE', 1),
#  ('OF', 217),
#  ('MINING', 1),
#  ('COM', 21),
#  ('XXXXXXXXXXXXXXXXXXXXXXXXXXXX', 1),
#  ('COD', 3),
#  ('RELEASE', 2),
#  ('ORDER', 3),
#  ('MOUSE', 1),
#  ('WINDOWS', 3),
#  ('US', 14),
#  ('EASE', 3),
#  ('NICK', 1),
#  ('GREAT', 9),
#  ('ONLINE', 2),
#  ('ZORK', 2),
#  ('L', 41),
#  ('GO', 55),
#  ('HOUSE', 4),
#  ('AROUND', 7),
#  ('BACK', 6),
#  ('OPEN', 5),
#  ('MAILBOX', 1),
#  ('READ', 1),
#  ('LEAFLET', 1),
#  ('PLAY', 2),
#  ('START', 4),
#  ('WALK', 1),
#  ('ACROSS', 1),
#  ('FIELD', 4),
#  ('LEFT', 1),
#  ('RIGHT', 6),
#  ('GOR', 1),
#  ('EAST', 12),
#  ('FING', 1),
#  ('WEST', 7),
#  ('CLIMB', 6),
#  ('TREE', 10),
#  ('LA', 7),
#  ('ARGE', 1),
#  ('TAKE', 7),
#  ('EGG', 4),
#  ('BREAK', 7),
#  ('FOOT', 1),
#  ('NOITH', 1),
#  ('OTHING', 1),
#  ('DO', 21),
#  ('NOT', 51),
#  ('ED', 15),
#  ('GG', 1),
#  ('UP', 24),
#  ('DOWN', 11),
#  ('CLIME', 1),
#  ('RT', 6),
#  ('REE', 2),
#  ('LARGE', 4),
#  ('JUMP', 4),
#  ('FORWARD', 9),
#  ('H', 20),
#  ('JUMOP', 1),
#  ('TOWARDS', 1),
#  ('SONG', 2),
#  ('BIRD', 3),
#  ('KILL', 2),
#  ('ROCLK', 1),
#  ('WITH', 61),
#  ('ROCK', 2),
#  ('FIND', 5),
#  ('LOOK', 10),
#  ('OUT', 14),
#  ('LOO', 1),
#  ('LEVE', 1),
#  ('FORREST', 1),
#  ('EXAMINE', 1),
#  ('PILE', 1),
#  ('LEAF', 1),
#  ('GRATING', 1),
#  ('LOCK', 2),
#  ('SOUTH', 6),
#  ('NORTH', 2),
#  ('GIO', 1),
#  ('O', 36),
#  ('NORTHWEST', 1),
#  ('HAND', 8),
#  ('CLIMDOWNB', 1),
#  ('DIO', 1),
#  ('EASGT', 1),
#  ('SUO', 1),
#  ('OUTH', 1),
#  ('OS', 2),
#  ('EST', 1),
#  ('RTH', 4),
#  ('NOTH', 1),
#  ('DOOR', 3),
#  ('DAMAGE', 1),
#  ('RAP', 3),
#  ('TRE', 2),
#  ('AP', 2),
#  ('ART', 5),
#  ('TRAP', 4),
#  ('DOR', 2),
#  ('OR', 54),
#  ('UNDER', 6),
#  ('RUG', 2),
#  ('TAR', 1),
#  ('RAPPED', 1),
#  ('MOVE', 3),
#  ('USE', 26),
#  ('LANTERN', 3),
#  ('EQUIPLA', 1),
#  ('CNUE', 1),
#  ('FORA', 1),
#  ('WAS', 29),
#  ('ARD', 2),
#  ('GKO', 1),
#  ('DDSDSAASDSASASASASASDSSASASSASDSDDWDSAWAWAWDWDWDWSAWAWDWAWAWAWA', 1),
#  ('ASSSDSASDSASASASASDSASDSWWAWASAWAWAWAWAWSDSDSSDWDWDWAWDWDWDWDWAWAWA', 1),
#  ('DAAA', 1),
#  ('K', 13),
#  ('ATTACK', 1),
#  ('SPIRT', 1),
#  ('RITS', 1),
#  ('WORS', 1),
#  ('ATTC', 1),
#  ('ACK', 1),
#  ('OST', 1),
#  ('HOST', 2),
#  ('SWORD', 4),
#  ('STAB', 1),
#  ('STZAB', 1),
#  ('FUC', 3),
#  ('FUSE', 1),
#  ('GHOST', 2),
#  ('BECOME', 4),
#  ('NUMB', 1),
#  ('CAN', 25),
#  ('SEE', 10),
#  ('THERR', 1),
#  ('THRE', 1),
#  ('TH', 25),
#  ('TALK', 2),
#  ('GHOSE', 1),
#  ('TKA', 1),
#  ('AKE', 1),
#  ('LK', 3),
#  ('GOS', 1),
#  ('TAK', 1),
#  ('HADES', 1),
#  ('INTO', 9),
#  ('HELL', 2),
#  ('THROUGH', 6),
#  ('GATE', 1),
#  ('LEAVE', 1),
#  ('TA', 4),
#  ('DIE', 7),
#  ('COMI', 1),
#  ('MIT', 1),
#  ('SUIS', 1),
#  ('CIDE', 1),
#  ('IRON', 2),
#  ('MAN', 5),
#  ('SCENE', 1),
#  ('AMAZON', 5),
#  ('BIX', 1),
#  ('BOX', 2),
#  ('CONDOMS', 3),
#  ('BIGGEST', 1),
#  ('SEINFELD', 1),
#  ('GEOG', 1),
#  ('RGE', 1),
#  ('DEFF', 1),
#  ('ECTIVE', 1),
#  ('SIMUTANEISM', 1),
#  ('GAME', 5),
#  ('AWD', 1),
#  ('DDADAS', 1),
#  ('DS', 1),
#  ('WAW', 1),
#  ('SDSA', 1),
#  ('LEO', 1),
#  ('AND', 281),
#  ('SATAN', 1),
#  ('ALGEBRA', 1),
#  ('ANIMATED', 1),
#  ('ADVENTURES', 1),
#  ('NASA', 1),
#  ('REDDIT', 9),
#  ('HEATR', 1),
#  ('TRTH', 1),
#  ('THSTONE', 1),
#  ('MURLOC', 1),
#  ('RAGNAROS', 2),
#  ('LEEROY', 1),
#  ('RA', 7),
#  ('CLA', 1),
#  ('MOODLE', 5),
#  ('CLARKSON', 19),
#  ('EDU', 2),
#  ('VIDEO', 6),
#  ('SOUND', 2),
#  ('TRACKS', 2),
#  ('HALO', 1),
#  ('REACH', 1),
#  ('SOUNDTRACK', 2),
#  ('Y', 94),
#  ('ONE', 29),
#  ('SYM', 5),
#  ('F', 71),
#  ('SIN', 11),
#  ('W', 49),
#  ('COS', 5),
#  ('TWH', 1),
#  ('THREE', 3),
#  ('SUBS', 5),
#  ('CLATR', 1),
#  ('KSON', 2),
#  ('TWO', 4),
#  ('FIGURE', 2),
#  ('EZPLOT', 1),
#  ('SYMS', 6),
#  ('YPIAZZA', 1),
#  ('PI', 4),
#  ('N', 67),
#  ('XC', 3),
#  ('HOLD', 4),
#  ('TITLE', 2),
#  ('XLABEL', 1),
#  ('YLABEL', 1),
#  ('PROBN', 1),
#  ('LEM', 1),
#  ('XS', 1),
#  ('SOLVE', 2),
#  ('FACTOR', 5),
#  ('DEFINES', 4),
#  ('SYMBOLIC', 4),
#  ('VARIABLES', 1),
#  ('EQUATION', 2),
#  ('FUNCTION', 7),
#  ('REPLACES', 4),
#  ('ALL', 22),
#  ('INSTANCES', 3),
#  ('CREATES', 5),
#  ('DEFIN', 1),
#  ('PARAMETERS', 1),
#  ('EZ', 1),
#  ('SATY', 1),
#  ('AST', 2),
#  ('PLOTS', 1),
#  ('GI', 1),
#  ('TITLES', 1),
#  ('FIGU', 1),
#  ('PLOT', 1),
#  ('LAV', 1),
#  ('BES', 1),
#  ('LABELS', 1),
#  ('AS', 88),
#  ('CIS', 1),
#  ('XIS', 1),
#  ('LABES', 1),
#  ('LS', 4),
#  ('AXIS', 1),
#  ('EXPRESSION', 1),
#  ('FACTORS', 2),
#  ('SDFDFS', 1),
#  ('ASDADS', 1),
#  ('QEWERWERWWER', 1),
#  ('WERWRWER', 1),
#  ('WDSASDADSAS', 1),
#  ('ERTSERT', 1),
#  ('ASDASD', 1),
#  ('YZ', 2),
#  ('XY', 4),
#  ('XZ', 1),
#  ('XYSDFGBEST', 1),
#  ('SOUNDRACK', 1),
#  ('TRACK', 4),
#  ('KLE', 1),
#  ('LEGEND', 2),
#  ('ZELDA', 2),
#  ('OC', 1),
#  ('CCARIN', 1),
#  ('ARINE', 1),
#  ('TIME', 14),
#  ('ASF', 1),
#  ('QWD', 1),
#  ('SDFSADF', 1),
#  ('XTHE', 1),
#  ('OCARINA', 1),
#  ('SOUNT', 1),
#  ('DR', 1),
#  ('TUBE', 3),
#  ('PLAYLIST', 1),
#  ('BLOONWS', 1),
#  ('AN', 27),
#  ('APP', 1),
#  ('PURCHASE', 2),
#  ('ION', 1),
#  ('PHONE', 5),
#  ('COMPUTER', 2),
#  ('BLOOM', 1),
#  ('NS', 2),
#  ('TD', 2),
#  ('GOP', 1),
#  ('GORDOGATOGORDOGATO', 1),
#  ('WEER', 1),
#  ('SUSTAINABLIYI', 1),
#  ('TDRIVE', 1),
#  ('DOCS', 4),
#  ('VJPOE', 1),
#  ('RACHETTA', 5),
#  ('MECHANICAL', 6),
#  ('ENGINEERING', 15),
#  ('MAJOE', 1),
#  ('POTSDAM', 5),
#  ('NY', 7),
#  ('DUCATION', 1),
#  ('UNIVERSITY', 5),
#  ('BAC', 1),
#  ('BACHELOR', 1),
#  ('SCIENCE', 3),
#  ('MAY', 25),
#  ('BACHELORS', 1),
#  ('OVER', 2),
#  ('GPA', 1),
#  ('PRESIDENTIAL', 1),
#  ('SCHOLAR', 1),
#  ('LIST', 7),
#  ('DRYDEN', 3),
#  ('HIGH', 5),
#  ('SCHOOL', 2),
#  ('BADVE', 1),
#  ('ANCED', 1),
#  ('DESIGA', 1),
#  ('NATION', 1),
#  ('DIPLOMA', 1),
#  ('HONORS', 1),
#  ('JUNE', 1),
#  ('NGINEERING', 1),
#  ('PROS', 1),
#  ('PROSTHTESTIC', 1),
#  ('ARM', 11),
#  ('DESIGN', 23),
#  ('PROJECT', 5),
#  ('BSPRING', 2),
#  ('SOCIETY', 8),
#  ('TEAM', 22),
#  ('LEADER', 1),
#  ('WORKED', 2),
#  ('FO', 5),
#  ('FOUR', 2),
#  ('OTHER', 18),
#  ('MEMBERS', 3),
#  ('DI', 8),
#  ('CREATE', 5),
#  ('PRSTH', 1),
#  ('OSTHETIC', 2),
#  ('WO', 6),
#  ('TEA', 1),
#  ('NAG', 1),
#  ('P', 39),
#  ('LESS', 5),
#  ('THAN', 7),
#  ('CONSTRATI', 1),
#  ('UI', 5),
#  ('NTS', 1),
#  ('BELECTRIC', 1),
#  ('TRAIN', 1),
#  ('LAB', 2),
#  ('BPHYSICS', 1),
#  ('II', 5),
#  ('SPRIN', 1),
#  ('BCOMPUTER', 1),
#  ('SKILLS', 3),
#  ('MI', 2),
#  ('MICROSOFT', 1),
#  ('OFFICE', 3),
#  ('MATLAB', 1),
#  ('GIOO', 2),
#  ('OGLE', 2),
#  ('SHEETS', 1),
#  ('FT', 5),
#  ('WORD', 1),
#  ('MICROS', 1),
#  ('POWERPOINT', 2),
#  ('EXCEL', 1),
#  ('ADOBE', 1),
#  ('OP', 7),
#  ('HOTOSHOP', 1),
#  ('LIMITED', 1),
#  ('MA', 2),
#  ('MATLANB', 1),
#  ('ZZ', 2),
#  ('BW', 1),
#  ('WORK', 16),
#  ('HIS', 3),
#  ('HISTORY', 6),
#  ('AMP', 1),
#  ('COUNSELR', 1),
#  ('ITHACA', 4),
#  ('CASS', 1),
#  ('PARK', 2),
#  ('DAY', 16),
#  ('CAMO', 1),
#  ('SUMMER', 5),
#  ('FREEVILLE', 1),
#  ('NYBRAVO', 1),
#  ('PIZZERIA', 1),
#  ('RESTAURANT', 1),
#  ('DISH', 1),
#  ('WASHER', 1),
#  ('DELIVERY', 1),
#  ('DRIVER', 1),
#  ('PORTS', 1),
#  ('ATHLETICS', 1),
#  ('CLARSK', 1),
#  ('INRA', 1),
#  ('TRAMURAL', 1),
#  ('SOCCER', 4),
#  ('VA', 1),
#  ('VARSIT', 1),
#  ('TY', 5),
#  ('SCHOLL', 1),
#  ('OL', 2),
#  ('SOC', 2),
#  ('CAPTIA', 1),
#  ('AIN', 1),
#  ('TORWELL', 1),
#  ('ORWELL', 1),
#  ('TAFT', 1),
#  ('GIRLFRIEND', 1),
#  ('VB', 1),
#  ('BEST', 12),
#  ('MOVIE', 2),
#  ('WATCH', 2),
#  ('WHEN', 14),
#  ('RE', 16),
#  ('MAMA', 1),
#  ('LUXC', 1),
#  ('CIAS', 1),
#  ('HONE', 1),
#  ('NUMBER', 7),
#  ('THER', 10),
#  ('REASON', 2),
#  ('WOULD', 46),
#  ('LIKE', 13),
#  ('BEE', 1),
#  ('PEER', 3),
#  ('EDUCATIO', 1),
#  ('NLY', 1),
#  ('DUE', 9),
#  ('FACT', 4),
#  ('LEARNED', 1),
#  ('LOT', 4),
#  ('FROM', 21),
#  ('EDUCATION', 1),
#  ('HE', 10),
#  ('REALLY', 2),
#  ('MADE', 7),
#  ('IT', 68),
#  ('EA', 2),
#  ('EASY', 2),
#  ('FRO', 1),
#  ('ME', 12),
#  ('COMFORTABLE', 3),
#  ('CAMPUS', 1),
#  ('FEEL', 5),
#  ('SOMEONE', 6),
#  ('ES', 14),
#  ('LSE', 1),
#  ('BE', 111),
#  ('ABLE', 16),
#  ('THANK', 4),
#  ('MUCH', 9),
#  ('WULREFERENCEHEYT', 1),
#  ('PROFESSOR', 4),
#  ('AM', 10),
#  ('APPLYING', 1),
#  ('EDUCATOR', 1),
#  ('WONDERING', 3),
#  ('IF', 41),
#  ('COULD', 21),
#  ('PUT', 4),
#  ('DOE', 1),
#  ('WN', 5),
#  ('REFERENCE', 1),
#  ('HO', 3),
#  ('EMULATOR', 1),
#  ('HILLARY', 1),
#  ('SWANK', 1),
#  ('CHILL', 1),
#  ('RFTYUTYUTYU', 1),
#  ('TYUTYU', 1),
#  ('WERWERWE', 1),
#  ('MARGO', 1),
#  ('CAREER', 2),
#  ('VC', 3),
#  ('FAIR', 3),
#  ('SET', 5),
#  ('UPI', 1),
#  ('SCHEDULES', 1),
#  ('SEC', 1),
#  ('SSION', 1),
#  ('TONIGHT', 1),
#  ('EVENING', 2),
#  ('WHERE', 6),
#  ('WRE', 2),
#  ('ARE', 59),
#  ('GOING', 12),
#  ('MEETINFG', 1),
#  ('LET', 3),
#  ('KNOW', 6),
#  ('HELPFUL', 3),
#  ('THANKS', 1),
#  ('VER', 1),
#  ('AGAIN', 1),
#  ('CORPA', 1),
#  ('ORATE', 1),
#  ('ARADICAL', 1),
#  ('J', 14),
#  ('RAI', 1),
#  ('IAN', 2),
#  ('BKAE', 1),
#  ('AKER', 1),
#  ('KEVIN', 4),
#  ('WELLS', 2),
#  ('EVAN', 2),
#  ('STUART', 2),
#  ('PAUL', 1),
#  ('ERIC', 2),
#  ('RODRIGUES', 2),
#  ('ZZZZ', 1),
#  ('OUR', 19),
#  ('GOALS', 5),
#  ('CLUDE', 1),
#  ('ONLY', 12),
#  ('CREATING', 3),
#  ('SUCCESSFUL', 7),
#  ('AL', 14),
#  ('PRODUCT', 8),
#  ('MEA', 1),
#  ('ETS', 1),
#  ('CONSTRAINTS', 3),
#  ('CAM', 2),
#  ('COMPLETE', 3),
#  ('THT', 1),
#  ('SPECIGF', 1),
#  ('FIED', 1),
#  ('CHALLENGWE', 1),
#  ('WE', 52),
#  ('WISH', 2),
#  ('ACOMPLISH', 1),
#  ('LEARN', 1),
#  ('COLLECTIVELY', 4),
#  ('LEAR', 1),
#  ('COMMUNICATIONS', 2),
#  ('MORE', 22),
#  ('ABOUT', 12),
#  ('PROCESS', 22),
#  ('WIL', 2),
#  ('TOOLS', 8),
#  ('SUCH', 9),
#  ('SPEECH', 1),
#  ('TEXTING', 1),
#  ('EMAIL', 3),
#  ('COMMUNICATEA', 1),
#  ('ESTABLISH', 3),
#  ('MEETING', 15),
#  ('TIMES', 1),
#  ('STORE', 2),
#  ('SHARED', 2),
#  ('FOLDER', 1),
#  ('GOO', 1),
#  ('GOOGKLE', 1),
#  ('LE', 4),
#  ('LOHG', 1),
#  ('BOOKS', 1),
#  ('RESPECTFUL', 2),
#  ('COMMUNICATION', 2),
#  ('IWLL', 1),
#  ('DEVELOP', 2),
#  ('BY', 11),
#  ('LOWING', 1),
#  ('YELLING', 1),
#  ('SUPPORTING', 1),
#  ('CONSTRUCTIVE', 1),
#  ('CI', 2),
#  ('RITIVI', 1),
#  ('CISM', 1),
#  ('OPPOSED', 3),
#  ('NEGATIVE', 1),
#  ('ATTIDU', 1),
#  ('TUDES', 1),
#  ('COMN', 1),
#  ('AGGRESSIVE', 1),
#  ('TR', 6),
#  ('ESPECTFUL', 1),
#  ('LLO', 1),
#  ('OOKS', 1),
#  ('SOUNDS', 1),
#  ('PEOS', 1),
#  ('PLE', 1),
#  ('HAVING', 3),
#  ('DISCUSSION', 4),
#  ('AT', 39),
#  ('REASONAL', 1),
#  ('BLE', 4),
#  ('VOLUMES', 2),
#  ('PERSON', 9),
#  ('ADDRESSED', 1),
#  ('IDEA', 3),
#  ('REST', 2),
#  ('LISTENS', 1),
#  ('WRITING', 1),
#  ('IDEAS', 7),
#  ('THEY', 44),
#  ('SHARE', 3),
#  ('WAITING', 4),
#  ('UNTIO', 1),
#  ('AFTER', 4),
#  ('FINISHED', 2),
#  ('PEAKING', 1),
#  ('ORGANIZE', 1),
#  ('MEETINGS', 5),
#  ('NEED', 8),
#  ('DISTRIBUTED', 1),
#  ('NA', 2),
#  ('ND', 8),
#  ('CHAT', 1),
#  ('EACH', 11),
#  ('DELIVERABLE', 6),
#  ('LEAD', 2),
#  ('AUTHORE', 1),
#  ('BTY', 3),
#  ('INDIVIDUAL', 5),
#  ('MEMBETR', 1),
#  ('IM', 1),
#  ('NPUT', 1),
#  ('AA', 1),
#  ('ASSISTANCE', 2),
#  ('RM', 1),
#  ('IO', 1),
#  ('OM', 2),
#  ('EVERYONE', 2),
#  ('SHAL', 2),
#  ('TREATS', 1),
#  ('EQUALL', 1),
#  ('THUS', 8),
#  ('AVOIDING', 1),
#  ('ANY', 17),
#  ('EVERTYONE', 1),
#  ('COL', 1),
#  ('THEIR', 25),
#  ('OWN', 6),
#  ('SCHEDULING', 1),
#  ('NBE', 1),
#  ('DONE', 1),
#  ('LEA', 1),
#  ('TRY', 4),
#  ('LIMIT', 1),
#  ('DIGRSE', 1),
#  ('ESSIONS', 1),
#  ('TOGETHER', 2),
#  ('MEET', 5),
#  ('NECESSARYT', 1),
#  ('PER', 2),
#  ('WEEK', 2),
#  ('WEEKEND', 1),
#  ('DURNI', 1),
#  ('ING', 14),
#  ('HTE', 1),
#  ('SOME', 10),
#  ('TI', 3),
#  ('DURING', 4),
#  ('EITHER', 2),
#  ('QUAD', 1),
#  ('CENTER', 1),
#  ('LOUNGE', 1),
#  ('DEPENDING', 2),
#  ('AVAILABILITY', 1),
#  ('AGENDA', 1),
#  ('DISCU', 1),
#  ('USSED', 1),
#  ('ADVANCE', 7),
#  ('BEGIG', 1),
#  ('MNN', 1),
#  ('NING', 1),
#  ('STAY', 1),
#  ('FOCUSED', 2),
#  ('TASK', 4),
#  ('DIGRESSIONS', 1),
#  ('ARISE', 1),
#  ('MATY', 3),
#  ('SERVE', 1),
#  ('KEEP', 1),
#  ('LIF', 2),
#  ('GHT', 2),
#  ('LONG', 7),
#  ('INFREQUENT', 1),
#  ('BRIEF', 3),
#  ('CA', 8),
#  ('RESPONSIBN', 1),
#  ('TAKING', 2),
#  ('NOTE', 1),
#  ('DETAILED', 2),
#  ('SA', 1),
#  ('RECON', 1),
#  ('RDS', 1),
#  ('UN', 1),
#  ('UNABLE', 2),
#  ('ATTEND', 1),
#  ('MEEYTIN', 1),
#  ('MEES', 1),
#  ('SSAGE', 1),
#  ('ALERTING', 1),
#  ('SH', 3),
#  ('INFORMATION', 5),
#  ('SHOULD', 12),
#  ('GIVEN', 1),
#  ('VIA', 1),
#  ('POSSIBLE', 3),
#  ('THEM', 18),
#  ('RESULTS', 2),
#  ('VIE', 1),
#  ('GROU', 1),
#  ('DOVS', 1),
#  ('CS', 1),
#  ('LATER', 1),
#  ('DATE', 2),
#  ('MAKE', 9),
#  ('DECISIONS', 2),
#  ('COLLECTIVELT', 1),
#  ('WQ', 1),
#  ('ORK', 2),
#  ('ASSIGNED', 1),
#  ('VOLUNTEER', 1),
#  ('BASIS', 1),
#  ('THEN', 4),
#  ('DIRECT', 1),
#  ('ASSIGNMENT', 2),
#  ('NECESSART', 1),
#  ('RY', 1),
#  ('WHO', 7),
#  ('HEN', 1),
#  ('THERE', 19),
#  ('ANO', 1),
#  ('YONE', 1),
#  ('SEND', 1),
#  ('REMINDER', 2),
#  ('REMIN', 1),
#  ('POLISH', 1),
#  ('DETAILS', 2),
#  ('DOES', 10),
#  ('NT', 2),
#  ('OT', 6),
#  ('WITHOUT', 7),
#  ('INFORMING', 1),
#  ('HELP', 8),
#  ('DOCUMENTED', 1),
#  ('FACRT', 1),
#  ('TORED', 1),
#  ('OUTR', 1),
#  ('REVIEDW', 1),
#  ('END', 9),
#  ('ER', 5),
#  ('ERSISTS', 1),
#  ('CONSISTANTLY', 1),
#  ('OCCURING', 1),
#  ('THI', 4),
#  ('PR', 2),
#  ('NOTIFIED', 1),
#  ('DIFFERING', 1),
#  ('PINIONS', 1),
#  ('QUAT', 2),
#  ('OUIR', 1),
#  ('DETICATIED', 1),
#  ('LITY', 1),
#  ('QUALITY', 4),
#  ('STANDO', 1),
#  ('MEMBER', 2),
#  ('DISCUSS', 2),
#  ('ISSUE', 3),
#  ('CORRECT', 1),
#  ('SIU', 1),
#  ('TUATION', 1),
#  ('RADFGDFGSDFG', 1),
#  ('DNE', 1),
#  ('JHRQ', 1),
#  ('HMHDNE', 1),
#  ('DFGASDASDASDASDASDASDASDASDASDASDASDASDASDASDASDASDDNE', 1),
#  ('EVRERY', 1),
#  ('YN', 1),
#  ('SOMETHING', 1),
#  ('NTRINB', 1),
#  ('BUTE', 1),
#  ('ANTY', 1),
#  ('TB', 1),
#  ('RECOGNIZE', 1),
#  ('THESE', 27),
#  ('TALENTS', 1),
#  ('GROUPS', 5),
#  ('APPLY', 2),
#  ('PERSONS', 1),
#  ('SLI', 1),
#  ('KILLS', 1),
#  ('BAND', 5),
#  ('KNOWLEDGE', 2),
#  ('WAY', 11),
#  ('BENEFITS', 4),
#  ('WHOLE', 3),
#  ('ST', 6),
#  ('SITS', 1),
#  ('UE', 4),
#  ('MEBER', 1),
#  ('BER', 1),
#  ('ANIMOSITY', 1),
#  ('ISUS', 1),
#  ('SUES', 1),
#  ('BROUGHT', 2),
#  ('ANS', 1),
#  ('OPENLY', 1),
#  ('DISCUSSED', 4),
#  ('SHALL', 3),
#  ('RELS', 1),
#  ('SOLE', 2),
#  ('VED', 1),
#  ('GETHER', 1),
#  ('FORUMM', 1),
#  ('DISPUTED', 1),
#  ('CSAN', 1),
#  ('UPOO', 1),
#  ('COMPLETION', 2),
#  ('PROH', 2),
#  ('JECT', 2),
#  ('GET', 7),
#  ('FOOD', 1),
#  ('TOGERTHER', 1),
#  ('HER', 5),
#  ('REW', 1),
#  ('WARD', 1),
#  ('THOSE', 6),
#  ('LINES', 2),
#  ('RIAN', 2),
#  ('PRINT', 6),
#  ('CREATED', 10),
#  ('HOMEWORK', 5),
#  ('LAST', 3),
#  ('EDITED', 2),
#  ('JOE', 6),
#  ('VOLUEM', 1),
#  ('NE', 3),
#  ('INPUT', 10),
#  ('ENTER', 10),
#  ('RADIUS', 2),
#  ('EN', 3),
#  ('HEIT', 1),
#  ('IEGHT', 1),
#  ('EIT', 1),
#  ('LENGTH', 8),
#  ('USER', 16),
#  ('INPUTS', 8),
#  ('DESIRED', 1),
#  ('RADISU', 1),
#  ('INPIU', 1),
#  ('TS', 6),
#  ('DESIT', 1),
#  ('RED', 3),
#  ('HEIGHT', 6),
#  ('CALCULATE', 1),
#  ('WIDTH', 5),
#  ('ENBT', 1),
#  ('TER', 1),
#  ('FPRINTF', 12),
#  ('VOLUME', 3),
#  ('PIAZZA', 1),
#  ('CALCULATES', 2),
#  ('PRINTS', 7),
#  ('DUIS', 1),
#  ('ISPLACE', 1),
#  ('OUTPUT', 3),
#  ('YS', 1),
#  ('APPLIED', 1),
#  ('FORCE', 3),
#  ('CROSS', 2),
#  ('SECTIONS', 1),
#  ('AREA', 2),
#  ('WW', 2),
#  ('WI', 5),
#  ('IDTH', 1),
#  ('IBNP', 1),
#  ('YOUNG', 4),
#  ('MODULO', 1),
#  ('MODULUS', 2),
#  ('SIGMA', 5),
#  ('DELTA', 5),
#  ('FPRING', 3),
#  ...]

# %%
sorted_word_occurences = sorted(tuple(filter(lambda x: len(x[0]) > 1, [(key, user_dict[key][ocnt]) for key in user_dict])), key = lambda x: x[1], reverse=True)
word = [f"{sorted_word_occurences[i][0]} "*sorted_word_occurences[i][1] for i in range(len(sorted_word_occurences))]
concat = "".join(word)
text_write = open("/Users/davidjohns/Desktop/Keystroke/nsf-reu2022/continuous_authentication/analysis/test.txt", "w")
text_to_file = text_write.write(concat)
text_write.close()
#concat

# %%
#word cloud with txt file 
text = open('test.txt').read()
stop_words = ["xxxx", "xxx", "xx","xxxxx"]
wc = wordcloud.WordCloud(collocations= False, background_color='white', height = 600, width = 1000, stopwords= stop_words)
wc.generate(text)

# save to file
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.show
wc.to_file('wordcloud_output.png')
